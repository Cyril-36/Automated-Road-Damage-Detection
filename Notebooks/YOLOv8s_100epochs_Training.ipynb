# %% [markdown]
# # 🚀 RDD2022 - YOLOv8s Training (100 Epochs)
#
# **Project:** Road Damage Detection
#
# **Model:** YOLOv8s @ 640×640
#
# **Training:** 100 epochs from scratch
#
# **Expected Duration:** 10-12 hours (T4 GPU)
#
# **Target:** 64-66% mAP@50
#
# ---
#
# ## 📋 Execution Order
# 1. **Cell 1:** Environment Setup (~3 min)
# 2. **Cell 2:** Extract Dataset (~5-10 min)
# 3. **Cell 3:** Create data.yaml (~1 min)
# 4. **Cell 4:** Training Config (~1 min)
# 5. **Cell 5:** Start Training (~10-12 hours) ⏰
# 6. **Cell 6:** Save to Drive (~5 min)
# 7. **Cell 7:** Results Analysis (~2 min)
# 8. **Cell 8:** Visualizations (~2 min)
# 9. **Cell 9:** Test Validation (~10 min)

# %%
# ============================================================================
# CELL 1: ENVIRONMENT SETUP
# ============================================================================

print("="*70)
print("YOLOv8s @ 640 - 100 EPOCH TRAINING (FRESH START)")
print("="*70)

import subprocess
import sys
import os

# Disable wandb
os.environ['WANDB_DISABLED'] = 'true'

# Check GPU
import torch
print(f"\n🎮 GPU Information:")
print(f"   GPU Available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"   GPU Name: {torch.cuda.get_device_name(0)}")
    print(f"   GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
    print(f"   CUDA Version: {torch.version.cuda}")

# Install Ultralytics
print(f"\n📦 Installing Ultralytics...")
subprocess.check_call([sys.executable, "-m", "pip", "install", "ultralytics", "-q"])

# Import libraries
from ultralytics import YOLO
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
from datetime import datetime
import shutil
import json
import yaml
import zipfile

print(f"\n✅ Setup complete!")
print(f"   Python: {sys.version.split()[0]}")
print(f"   PyTorch: {torch.__version__}")
print(f"   Ultralytics: Installed")
print("="*70)
# Out:
# ======================================================================
# YOLOv8s @ 640 - 100 EPOCH TRAINING (FRESH START)
# ======================================================================
#
# 🎮 GPU Information:
#    GPU Available: True
#    GPU Name: NVIDIA A100-SXM4-40GB
#    GPU Memory: 39.6 GB
#    CUDA Version: 12.6
#
# 📦 Installing Ultralytics...
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
#
# ✅ Setup complete!
#    Python: 3.12.12
#    PyTorch: 2.9.0+cu126
#    Ultralytics: Installed
# ======================================================================

# %%
# ============================================================================
# CELL 2: MOUNT GOOGLE DRIVE & EXTRACT DATASET
# ============================================================================

print("="*70)
print("GOOGLE DRIVE & DATASET EXTRACTION")
print("="*70)

# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
print("✅ Google Drive mounted\n")

# Path to your ZIP file in Drive
ZIP_PATH = '/content/drive/MyDrive/RDD.zip'
EXTRACT_PATH = '/content/RDD2022'

# Check if ZIP exists
zip_file = Path(ZIP_PATH)
if not zip_file.exists():
    print(f"❌ ZIP file not found: {ZIP_PATH}")
    print("Please check the file name and path in your Drive")
else:
    size_gb = zip_file.stat().st_size / (1024**3)
    print(f"✅ Found ZIP file: {zip_file.name}")
    print(f"   Size: {size_gb:.2f} GB")

    # Extract ZIP
    print(f"\n📦 Extracting dataset...")
    print(f"   From: {ZIP_PATH}")
    print(f"   To: {EXTRACT_PATH}")
    print(f"   This will take ~5-10 minutes...\n")

    with zipfile.ZipFile(ZIP_PATH, 'r') as zip_ref:
        # Extract with progress
        members = zip_ref.namelist()
        total = len(members)
        for i, member in enumerate(members, 1):
            zip_ref.extract(member, EXTRACT_PATH)
            if i % 1000 == 0:
                print(f"   Extracted {i}/{total} files ({i/total*100:.1f}%)")

    print(f"\n✅ Extraction complete!")

# Find the actual dataset folder
extract_dir = Path(EXTRACT_PATH)
possible_paths = [
    extract_dir / 'RDD_SPLIT',
    extract_dir / 'RDD2022',
    extract_dir,
]

dataset_path = None
for path in possible_paths:
    if (path / 'train' / 'images').exists():
        dataset_path = path
        break

if dataset_path is None:
    print("\n⚠️ Dataset structure not found in expected locations. Searching...")
    # Search for train folder
    for item in extract_dir.rglob('train'):
        if (item / 'images').exists():
            dataset_path = item.parent
            break

if dataset_path:
    print(f"\n✅ Dataset found: {dataset_path}")
    print(f"\n📊 Dataset Statistics:")

    total_images = 0
    total_labels = 0

    for split in ['train', 'val', 'test']:
        img_path = dataset_path / split / 'images'
        lbl_path = dataset_path / split / 'labels'

        if img_path.exists() and lbl_path.exists():
            n_images = len(list(img_path.glob('*.jpg')))
            n_labels = len(list(lbl_path.glob('*.txt')))
            total_images += n_images
            total_labels += n_labels
            print(f"   {split:5s}: {n_images:6,d} images, {n_labels:6,d} labels")

    print(f"\n   TOTAL: {total_images:6,d} images, {total_labels:6,d} labels")

else:
    print("\n❌ Could not find dataset structure")
    print("   Please check the ZIP file contents")

print("="*70)
# Out:
# ======================================================================
# GOOGLE DRIVE & DATASET EXTRACTION
# ======================================================================
# Mounted at /content/drive
# ✅ Google Drive mounted
#
# ✅ Found ZIP file: RDD.zip
#    Size: 9.90 GB
#
# 📦 Extracting dataset...
#    From: /content/drive/MyDrive/RDD.zip
#    To: /content/RDD2022
#    This will take ~5-10 minutes...
#
#    Extracted 1000/76770 files (1.3%)
#    Extracted 2000/76770 files (2.6%)
#    Extracted 3000/76770 files (3.9%)
#    Extracted 4000/76770 files (5.2%)
#    Extracted 5000/76770 files (6.5%)
#    Extracted 6000/76770 files (7.8%)
#    Extracted 7000/76770 files (9.1%)
#    Extracted 8000/76770 files (10.4%)
#    Extracted 9000/76770 files (11.7%)
#    Extracted 10000/76770 files (13.0%)
#    Extracted 11000/76770 files (14.3%)
#    Extracted 12000/76770 files (15.6%)
#    Extracted 13000/76770 files (16.9%)
#    Extracted 14000/76770 files (18.2%)
#    Extracted 15000/76770 files (19.5%)
#    Extracted 16000/76770 files (20.8%)
#    Extracted 17000/76770 files (22.1%)
#    Extracted 18000/76770 files (23.4%)
#    Extracted 19000/76770 files (24.7%)
#    Extracted 20000/76770 files (26.1%)
#    Extracted 21000/76770 files (27.4%)
#    Extracted 22000/76770 files (28.7%)
#    Extracted 23000/76770 files (30.0%)
#    Extracted 24000/76770 files (31.3%)
#    Extracted 25000/76770 files (32.6%)
#    Extracted 26000/76770 files (33.9%)
#    Extracted 27000/76770 files (35.2%)
#    Extracted 28000/76770 files (36.5%)
#    Extracted 29000/76770 files (37.8%)
#    Extracted 30000/76770 files (39.1%)
#    Extracted 31000/76770 files (40.4%)
#    Extracted 32000/76770 files (41.7%)
#    Extracted 33000/76770 files (43.0%)
#    Extracted 34000/76770 files (44.3%)
#    Extracted 35000/76770 files (45.6%)
#    Extracted 36000/76770 files (46.9%)
#    Extracted 37000/76770 files (48.2%)
#    Extracted 38000/76770 files (49.5%)
#    Extracted 39000/76770 files (50.8%)
#    Extracted 40000/76770 files (52.1%)
#    Extracted 41000/76770 files (53.4%)
#    Extracted 42000/76770 files (54.7%)
#    Extracted 43000/76770 files (56.0%)
#    Extracted 44000/76770 files (57.3%)
#    Extracted 45000/76770 files (58.6%)
#    Extracted 46000/76770 files (59.9%)
#    Extracted 47000/76770 files (61.2%)
#    Extracted 48000/76770 files (62.5%)
#    Extracted 49000/76770 files (63.8%)
#    Extracted 50000/76770 files (65.1%)
#    Extracted 51000/76770 files (66.4%)
#    Extracted 52000/76770 files (67.7%)
#    Extracted 53000/76770 files (69.0%)
#    Extracted 54000/76770 files (70.3%)
#    Extracted 55000/76770 files (71.6%)
#    Extracted 56000/76770 files (72.9%)
#    Extracted 57000/76770 files (74.2%)
#    Extracted 58000/76770 files (75.6%)
#    Extracted 59000/76770 files (76.9%)
#    Extracted 60000/76770 files (78.2%)
#    Extracted 61000/76770 files (79.5%)
#    Extracted 62000/76770 files (80.8%)
#    Extracted 63000/76770 files (82.1%)
#    Extracted 64000/76770 files (83.4%)
#    Extracted 65000/76770 files (84.7%)
#    Extracted 66000/76770 files (86.0%)
#    Extracted 67000/76770 files (87.3%)
#    Extracted 68000/76770 files (88.6%)
#    Extracted 69000/76770 files (89.9%)
#    Extracted 70000/76770 files (91.2%)
#    Extracted 71000/76770 files (92.5%)
#    Extracted 72000/76770 files (93.8%)
#    Extracted 73000/76770 files (95.1%)
#    Extracted 74000/76770 files (96.4%)
#    Extracted 75000/76770 files (97.7%)
#    Extracted 76000/76770 files (99.0%)
#
# ✅ Extraction complete!
#
# ✅ Dataset found: /content/RDD2022/RDD_SPLIT
#
# 📊 Dataset Statistics:
#    train: 26,869 images, 26,869 labels
#    val  :  5,758 images,  5,758 labels
#    test :  5,758 images,  5,758 labels
#
#    TOTAL: 38,385 images, 38,385 labels
# ======================================================================

# %%
# ============================================================================
# CELL 3: CREATE DATA.YAML
# ============================================================================

print("="*70)
print("CREATING DATA.YAML")
print("="*70)

if dataset_path is None:
    print("❌ Dataset path not set - run Cell 2 first")
else:
    # Define classes
    classes = [
        'longitudinal crack',
        'transverse crack',
        'alligator crack',
        'other corruption',
        'Pothole'
    ]

    # Create data.yaml
    data_yaml = {
        'path': str(dataset_path),
        'train': 'train/images',
        'val': 'val/images',
        'test': 'test/images',
        'nc': len(classes),
        'names': classes
    }

    yaml_path = Path('/content/data.yaml')
    with open(yaml_path, 'w') as f:
        yaml.dump(data_yaml, f, sort_keys=False)

    print(f"✅ data.yaml created: {yaml_path}")
    print(f"\n📊 Configuration:")
    print(f"   Dataset Path: {dataset_path}")
    print(f"   Classes: {len(classes)}")
    for i, cls in enumerate(classes):
        print(f"      {i}: {cls}")

    # Display data.yaml content
    print(f"\n📄 data.yaml content:")
    with open(yaml_path, 'r') as f:
        print(f.read())

print("="*70)
# Out:
# ======================================================================
# CREATING DATA.YAML
# ======================================================================
# ✅ data.yaml created: /content/data.yaml
#
# 📊 Configuration:
#    Dataset Path: /content/RDD2022/RDD_SPLIT
#    Classes: 5
#       0: longitudinal crack
#       1: transverse crack
#       2: alligator crack
#       3: other corruption
#       4: Pothole
#
# 📄 data.yaml content:
# path: /content/RDD2022/RDD_SPLIT
# train: train/images
# val: val/images
# test: test/images
# nc: 5
# names:
# - longitudinal crack
# - transverse crack
# - alligator crack
# - other corruption
# - Pothole
#
# ======================================================================

# %%
# ============================================================================
# CELL 4: TRAINING CONFIGURATION (100 EPOCHS)
# ============================================================================

print("="*70)
print("TRAINING CONFIGURATION - 100 EPOCHS FROM SCRATCH")
print("="*70)

# Training configuration
TRAINING_CONFIG = {
    # Model & Data
    'model': 'yolov8s.pt',              # Fresh YOLOv8s model
    'data': '/content/data.yaml',

    # Training parameters
    'epochs': 100,                      # Full 100 epochs
    'imgsz': 640,
    'batch': 16,                        # T4 GPU can handle 16
    'device': 0,
    'workers': 8,                       # Colab has more CPU cores

    # Validation & Saving
    'patience': 20,
    'save': True,
    'save_period': 10,                  # Save every 10 epochs
    'val': True,
    'plots': True,

    # Optimization
    'cache': True,                      # Cache images in RAM
    'amp': True,                        # Mixed precision
    'close_mosaic': 10,

    # Output
    'project': '/content/runs',
    'name': 'yolov8s_640_100epochs',
    'exist_ok': False,
    'verbose': True,

    # Optimizer
    'optimizer': 'SGD',
    'lr0': 0.01,
    'lrf': 0.01,
    'momentum': 0.937,
    'weight_decay': 0.0005,
    'warmup_epochs': 3.0,
    'warmup_momentum': 0.8,
    'warmup_bias_lr': 0.1,

    # Loss weights
    'box': 7.5,
    'cls': 0.5,
    'dfl': 1.5,

    # Augmentation
    'hsv_h': 0.015,
    'hsv_s': 0.7,
    'hsv_v': 0.4,
    'degrees': 0.0,
    'translate': 0.1,
    'scale': 0.5,
    'shear': 0.0,
    'perspective': 0.0,
    'flipud': 0.0,
    'fliplr': 0.5,
    'mosaic': 1.0,
    'mixup': 0.0,
    'copy_paste': 0.0,
}

print("\n📊 Configuration Summary:")
print(f"   Model: YOLOv8s (11.1M parameters)")
print(f"   Resolution: 640×640")
print(f"   Epochs: {TRAINING_CONFIG['epochs']}")
print(f"   Batch Size: {TRAINING_CONFIG['batch']}")
print(f"   Workers: {TRAINING_CONFIG['workers']}")
print(f"   Optimizer: {TRAINING_CONFIG['optimizer']}")
print(f"   Learning Rate: {TRAINING_CONFIG['lr0']}")

print(f"\n⏱️ Estimated Duration:")
print(f"   T4 GPU: ~10-12 hours")
print(f"   A100 GPU: ~4-5 hours")
print(f"   Session Limit: 24 hours ✅ SAFE")

print(f"\n🎯 Expected Results:")
print(f"   Target mAP@50: 64-66%")
print(f"   Baseline (YOLOv8n): 58.82%")
print(f"   Expected Improvement: +5-7%")

print("="*70)
# Out:
# ======================================================================
# TRAINING CONFIGURATION - 100 EPOCHS FROM SCRATCH
# ======================================================================
#
# 📊 Configuration Summary:
#    Model: YOLOv8s (11.1M parameters)
#    Resolution: 640×640
#    Epochs: 100
#    Batch Size: 16
#    Workers: 8
#    Optimizer: SGD
#    Learning Rate: 0.01
#
# ⏱️ Estimated Duration:
#    T4 GPU: ~10-12 hours
#    A100 GPU: ~4-5 hours
#    Session Limit: 24 hours ✅ SAFE
#
# 🎯 Expected Results:
#    Target mAP@50: 64-66%
#    Baseline (YOLOv8n): 58.82%
#    Expected Improvement: +5-7%
# ======================================================================

# %%
# ============================================================================
# CELL 5: START TRAINING (With Auto-Resume Safety)
# ============================================================================

from ultralytics import YOLO
from datetime import datetime
from pathlib import Path

print("="*70)
print("🚀 STARTING TRAINING - 100 EPOCHS (AUTO-RESUME ENABLED)")
print("="*70)

# Check for existing checkpoint to resume
last_ckpt = Path('/content/runs/yolov8s_640_100epochs/weights/last.pt')

if last_ckpt.exists():
    print(f"\n⚠️ Found existing checkpoint: {last_ckpt}")
    size_mb = last_ckpt.stat().st_size / (1024 * 1024)
    print(f"   Checkpoint Size: {size_mb:.1f} MB")
    print("   🔄 RESUMING training from where it stopped...")
    model = YOLO(str(last_ckpt))
    resume_mode = True
else:
    print("\n✅ No checkpoint found - Starting FRESH training from scratch...")
    model = YOLO('yolov8s.pt')
    resume_mode = False

print(f"\n⏰ Start Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print("="*70 + "\n")

try:
    # If resuming, use resume=True (preserves all training state)
    if resume_mode:
        print("🔄 Resuming with preserved training state...\n")
        results = model.train(resume=True)
    else:
        print("🆕 Starting fresh training...\n")
        results = model.train(**TRAINING_CONFIG)

    print("\n" + "="*70)
    print("🎉 TRAINING COMPLETED SUCCESSFULLY!")
    print("="*70)
    print(f"⏰ End Time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")

except KeyboardInterrupt:
    print("\n⚠️ Training interrupted by user")
    print("💾 Checkpoint saved - you can resume by re-running this cell")

except Exception as e:
    print(f"\n❌ Training Error: {e}")
    print("💾 Attempting to save current state...")
    print("   Re-run this cell to resume from last checkpoint")
    import traceback
    traceback.print_exc()
# Out:
# ======================================================================
# 🚀 STARTING TRAINING - 100 EPOCHS (AUTO-RESUME ENABLED)
# ======================================================================
#
# ✅ No checkpoint found - Starting FRESH training from scratch...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt': 100% ━━━━━━━━━━━━ 21.5MB 69.9MB/s 0.3s
#
# ⏰ Start Time: 2025-12-13 03:35:34
# ======================================================================
#
# 🆕 Starting fresh training...
#
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# engine/trainer: agnostic_nms=False, amp=True, augment=False, auto_augment=randaugment, batch=16, bgr=0.0, box=7.5, cache=True, cfg=None, classes=None, close_mosaic=10, cls=0.5, compile=False, conf=None, copy_paste=0.0, copy_paste_mode=flip, cos_lr=False, cutmix=0.0, data=/content/data.yaml, degrees=0.0, deterministic=True, device=0, dfl=1.5, dnn=False, dropout=0.0, dynamic=False, embed=None, epochs=100, erasing=0.4, exist_ok=False, fliplr=0.5, flipud=0.0, format=torchscript, fraction=1.0, freeze=None, half=False, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, imgsz=640, int8=False, iou=0.7, keras=False, kobj=1.0, line_width=None, lr0=0.01, lrf=0.01, mask_ratio=4, max_det=300, mixup=0.0, mode=train, model=yolov8s.pt, momentum=0.937, mosaic=1.0, multi_scale=False, name=yolov8s_640_100epochs, nbs=64, nms=False, opset=None, optimize=False, optimizer=SGD, overlap_mask=True, patience=20, perspective=0.0, plots=True, pose=12.0, pretrained=True, profile=False, project=/content/runs, rect=False, resume=False, retina_masks=False, save=True, save_conf=False, save_crop=False, save_dir=/content/runs/yolov8s_640_100epochs, save_frames=False, save_json=False, save_period=10, save_txt=False, scale=0.5, seed=0, shear=0.0, show=False, show_boxes=True, show_conf=True, show_labels=True, simplify=True, single_cls=False, source=None, split=val, stream_buffer=False, task=detect, time=None, tracker=botsort.yaml, translate=0.1, val=True, verbose=True, vid_stride=1, visualize=False, warmup_bias_lr=0.1, warmup_epochs=3.0, warmup_momentum=0.8, weight_decay=0.0005, workers=8, workspace=None
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf': 100% ━━━━━━━━━━━━ 755.1KB 14.5MB/s 0.1s
# Overriding model.yaml nc=80 with nc=5
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2117983  ultralytics.nn.modules.head.Detect           [5, [128, 256, 512]]
# Model summary: 129 layers, 11,137,535 parameters, 11,137,519 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt': 100% ━━━━━━━━━━━━ 5.4MB 69.3MB/s 0.1s
# AMP: checks passed ✅
# train: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1941.5±518.8 MB/s, size: 66.0 KB)
# train: Scanning /content/RDD2022/RDD_SPLIT/train/labels... 26869 images, 8097 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 26869/26869 1.6Kit/s 16.5s
# train: /content/RDD2022/RDD_SPLIT/train/images/Japan_006916.jpg: 1 duplicate labels removed
# train: /content/RDD2022/RDD_SPLIT/train/images/Japan_011427.jpg: 1 duplicate labels removed
# train: New cache created: /content/RDD2022/RDD_SPLIT/train/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# train: Caching images (27.7GB RAM): 100% ━━━━━━━━━━━━ 26869/26869 570.3it/s 47.1s
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 559.7±221.5 MB/s, size: 263.6 KB)
# val: Scanning /content/RDD2022/RDD_SPLIT/val/labels... 5758 images, 1837 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5758/5758 1.5Kit/s 3.9s
# val: /content/RDD2022/RDD_SPLIT/val/images/Japan_006536.jpg: 1 duplicate labels removed
# val: New cache created: /content/RDD2022/RDD_SPLIT/val/labels.cache
# WARNING ⚠️ cache='ram' may produce non-deterministic training results. Consider cache='disk' as a deterministic alternative if your disk space allows.
# val: Caching images (5.9GB RAM): 100% ━━━━━━━━━━━━ 5758/5758 536.4it/s 10.7s
# Plotting labels to /content/runs/yolov8s_640_100epochs/labels.jpg...
# optimizer: SGD(lr=0.01, momentum=0.937) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to /content/runs/yolov8s_640_100epochs
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      3.49G      1.984       2.88       1.75         16        640: 100% ━━━━━━━━━━━━ 1680/1680 10.4it/s 2:41
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 8.3it/s 21.7s
#                    all       5758       9740      0.362      0.269      0.226      0.104
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      4.63G      1.893      2.288      1.632          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.9s
#                    all       5758       9740      0.405       0.35      0.317      0.144
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      4.65G      1.991      2.435       1.73         23        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.0s
#                    all       5758       9740      0.364      0.307      0.251      0.106
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      4.68G      2.003      2.476      1.778          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 19.9s
#                    all       5758       9740      0.402      0.337      0.302      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       4.7G      1.929      2.336      1.725         12        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 8.9it/s 20.2s
#                    all       5758       9740      0.439      0.383      0.354      0.164
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      4.73G      1.881      2.228      1.682         20        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 19.9s
#                    all       5758       9740      0.462      0.404      0.377      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      4.75G      1.845      2.152      1.657         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 19.9s
#                    all       5758       9740      0.483      0.421      0.403      0.192
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      4.77G      1.813      2.091      1.638         22        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.0s
#                    all       5758       9740      0.499      0.441       0.43       0.21
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100       4.8G      1.801      2.056      1.625         19        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.509      0.453      0.447      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      4.82G      1.779      2.015      1.608         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.511      0.458      0.455      0.228
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      4.85G      1.757      1.972       1.59         14        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 19.9s
#                    all       5758       9740      0.549      0.473      0.487      0.245
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      4.87G      1.749      1.959      1.591         17        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.7s
#                    all       5758       9740      0.543      0.486      0.488      0.249
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100       4.9G      1.729      1.909      1.571          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.572      0.481      0.502      0.257
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      4.92G      1.714      1.886      1.561          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740      0.571      0.497      0.515      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      4.94G      1.708      1.868      1.555         11        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.9s
#                    all       5758       9740      0.572      0.514      0.526      0.274
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      4.97G      1.697      1.845      1.542         18        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.568      0.514      0.527      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      4.99G      1.686      1.822      1.529         26        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.573      0.526      0.538      0.284
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      5.02G      1.679      1.809      1.534         22        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.594      0.522      0.546      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      5.04G      1.672      1.789      1.517         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.606      0.522       0.55      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      5.06G      1.668      1.773       1.52         10        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 19.9s
#                    all       5758       9740      0.596      0.531      0.556      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100      5.09G      1.665      1.762      1.511         15        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.602       0.53      0.563      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      5.11G      1.657      1.752      1.506         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740      0.608      0.531      0.561      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      5.14G       1.65      1.731      1.497         46        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.616      0.534      0.571      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      5.16G      1.643      1.723      1.498          8        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.612      0.548      0.575       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      5.19G      1.636      1.711      1.492         11        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740       0.62      0.545      0.575      0.309
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      5.21G       1.63      1.694      1.488         10        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.625      0.547      0.582      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      5.23G      1.624       1.69      1.484         30        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.1s
#                    all       5758       9740      0.617      0.556      0.583      0.315
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      5.26G      1.622      1.667      1.481          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740      0.628       0.55      0.584      0.316
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      5.28G      1.615      1.664      1.476         16        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 8.9it/s 20.2s
#                    all       5758       9740      0.617      0.562      0.587      0.318
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      5.31G      1.611      1.653      1.469          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.1s
#                    all       5758       9740      0.616      0.559      0.588       0.32
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      5.33G      1.612       1.64      1.467         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 8.9it/s 20.2s
#                    all       5758       9740      0.619      0.562      0.592      0.322
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      5.36G      1.597      1.631      1.466         20        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.9s
#                    all       5758       9740      0.624      0.562      0.595      0.324
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      5.38G      1.596      1.615      1.459         35        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.0s
#                    all       5758       9740      0.624      0.566      0.597      0.325
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100       5.4G      1.586      1.604      1.453          1        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 19.9s
#                    all       5758       9740      0.627      0.569      0.601      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      5.43G      1.584      1.596      1.451         20        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.0s
#                    all       5758       9740      0.623      0.573      0.601      0.327
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      5.45G       1.58      1.592      1.447         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.0s
#                    all       5758       9740      0.629      0.568      0.603      0.328
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      5.48G      1.576      1.581      1.444         10        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.1s
#                    all       5758       9740      0.629      0.571      0.604      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100       5.5G      1.576      1.572      1.439          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:32
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.4it/s 19.2s
#                    all       5758       9740      0.632      0.571      0.605      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      5.53G      1.571      1.561      1.437          6        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.637      0.571      0.606       0.33
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      5.55G      1.572      1.558      1.434          4        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.0it/s 20.0s
#                    all       5758       9740      0.634      0.574      0.606      0.331
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      5.58G       1.56      1.548      1.426         15        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.629      0.578      0.607      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100       5.6G      1.556      1.532      1.425         19        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.628      0.577      0.607      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      5.62G      1.548      1.518      1.421          6        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740       0.63      0.577      0.607      0.332
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      5.65G      1.549      1.518      1.415         18        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.4it/s 19.2s
#                    all       5758       9740       0.63      0.578      0.607      0.333
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      5.67G      1.543      1.513      1.414         16        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740      0.628      0.581      0.608      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100       5.7G      1.532      1.491      1.405         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740      0.627      0.579      0.609      0.334
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      5.72G      1.536      1.483       1.41         11        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.629      0.581       0.61      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      5.75G      1.531      1.479      1.403          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.625      0.584      0.611      0.335
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      5.77G      1.531      1.474        1.4         16        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.631      0.581       0.61      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      5.79G      1.524      1.461      1.394          8        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740       0.63      0.582      0.611      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      5.82G      1.514       1.46      1.392         12        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740       0.63      0.582      0.611      0.336
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      5.84G      1.519      1.439      1.391         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.634      0.583      0.612      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      5.87G      1.512      1.433      1.383         12        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.633      0.584      0.612      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      5.89G      1.505      1.417      1.379         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.636      0.584      0.613      0.337
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100      5.91G      1.503      1.413       1.38         10        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.635      0.585      0.613      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      5.94G      1.492      1.409      1.372         24        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 8.9it/s 20.2s
#                    all       5758       9740      0.631      0.587      0.614      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      5.96G      1.496      1.416      1.371         11        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740      0.633      0.587      0.614      0.338
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      5.99G      1.488      1.395      1.367          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.7s
#                    all       5758       9740      0.633      0.589      0.614      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      6.01G      1.486      1.391      1.365         15        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.635      0.589      0.615      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      6.04G      1.478      1.371      1.359          8        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.636       0.59      0.617      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100      6.06G      1.471      1.365      1.359         15        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.7s
#                    all       5758       9740       0.64      0.588      0.617      0.339
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      6.18G      1.473      1.361      1.358          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.641      0.588      0.617       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      6.21G      1.464      1.348      1.348         12        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.642      0.587      0.617       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      6.23G      1.458      1.331      1.344         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.643      0.588      0.618       0.34
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      6.26G      1.458      1.322      1.345         12        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.644      0.589      0.618      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      6.39G      1.452       1.32      1.343         14        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.647      0.585      0.618      0.341
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      6.41G      1.445      1.313      1.335         10        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.4s
#                    all       5758       9740      0.645      0.586      0.619      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      6.44G      1.447      1.306      1.335         12        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.649      0.583      0.619      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      6.46G      1.435      1.292      1.328         21        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.649      0.582      0.619      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      6.48G      1.434      1.276      1.328         15        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.651      0.581       0.62      0.342
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      6.51G      1.427      1.273      1.318          8        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.654      0.581      0.621      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      6.53G      1.416      1.264      1.316          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.653      0.581      0.621      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      6.65G       1.42      1.256      1.314         12        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.656      0.577      0.621      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      6.67G      1.409      1.238      1.304         21        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.658      0.576      0.622      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100       6.7G      1.403      1.233      1.302         19        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.661      0.575      0.621      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      6.72G      1.397      1.227      1.297          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.661      0.576      0.622      0.343
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      6.84G      1.397      1.214        1.3          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.4it/s 19.3s
#                    all       5758       9740      0.661      0.576      0.622      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      6.86G      1.384      1.201      1.294          6        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.661      0.576      0.623      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      6.88G      1.379      1.193      1.285         10        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.4it/s 19.1s
#                    all       5758       9740      0.661      0.577      0.623      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      6.91G      1.376      1.193      1.289         19        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.7s
#                    all       5758       9740      0.662      0.578      0.623      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      6.93G       1.37      1.173       1.28         11        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740       0.66      0.579      0.623      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      6.96G      1.362      1.163      1.274         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.662       0.58      0.623      0.344
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.07G      1.357      1.157      1.272          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.1it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.662       0.58      0.624      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100       7.1G      1.352      1.146      1.266         11        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.8s
#                    all       5758       9740      0.663       0.58      0.624      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.12G      1.346      1.138      1.265         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740       0.66      0.583      0.624      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100      7.25G      1.334      1.123      1.258         19        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740       0.66      0.583      0.624      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.27G      1.338      1.118      1.258         15        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:31
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.657      0.585      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100       7.3G       1.33      1.108      1.252         14        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.657      0.586      0.624      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.32G      1.329      1.103      1.252          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.5it/s 18.9s
#                    all       5758       9740      0.662      0.582      0.624      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      7.35G      1.311      1.084      1.244         11        640: 100% ━━━━━━━━━━━━ 1680/1680 11.2it/s 2:30
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.662      0.583      0.625      0.345
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, method='weighted_average', num_output_channels=3), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      7.37G      1.297      0.991       1.26          4        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:29
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.1it/s 19.7s
#                    all       5758       9740      0.665      0.582      0.625      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.48G      1.283     0.9613      1.249          8        640: 100% ━━━━━━━━━━━━ 1680/1680 11.3it/s 2:28
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.666      0.581      0.625      0.346
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100       7.5G      1.269     0.9459      1.245          7        640: 100% ━━━━━━━━━━━━ 1680/1680 11.4it/s 2:27
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.4it/s 19.2s
#                    all       5758       9740      0.668      0.581      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.53G      1.257     0.9354      1.238          9        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.671       0.58      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.55G       1.25      0.913      1.231          8        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.4it/s 19.2s
#                    all       5758       9740      0.671      0.581      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      7.67G      1.242     0.9025      1.226          6        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.671      0.582      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.69G       1.23     0.8926       1.22          8        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.6s
#                    all       5758       9740      0.669      0.582      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      7.72G      1.221     0.8873      1.218         13        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.2it/s 19.5s
#                    all       5758       9740      0.671       0.58      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.74G      1.213     0.8728       1.21          5        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.4it/s 19.2s
#                    all       5758       9740      0.676      0.576      0.625      0.345
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.76G      1.205     0.8658      1.205          3        640: 100% ━━━━━━━━━━━━ 1680/1680 11.5it/s 2:26
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 9.3it/s 19.3s
#                    all       5758       9740      0.676      0.575      0.625      0.344
#
# 100 epochs completed in 4.679 hours.
# Optimizer stripped from /content/runs/yolov8s_640_100epochs/weights/last.pt, 22.5MB
# Optimizer stripped from /content/runs/yolov8s_640_100epochs/weights/best.pt, 22.5MB
#
# Validating /content/runs/yolov8s_640_100epochs/weights/best.pt...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 180/180 8.7it/s 20.8s
#                    all       5758       9740      0.664      0.583      0.626      0.345
#     longitudinal crack       2011       3890      0.645      0.548      0.587      0.332
#       transverse crack       1158       1769      0.641      0.537      0.575      0.289
#        alligator crack       1222       1553      0.677      0.641      0.687      0.375
#       other corruption       1093       1563      0.699      0.762      0.782      0.498
#                Pothole        544        965      0.658      0.426      0.497      0.233
# Speed: 0.1ms preprocess, 0.7ms inference, 0.0ms loss, 0.8ms postprocess per image
# Results saved to /content/runs/yolov8s_640_100epochs
#
# ======================================================================
# 🎉 TRAINING COMPLETED SUCCESSFULLY!
# ======================================================================
# ⏰ End Time: 2025-12-13 08:18:32

# %%
# ============================================================================
# CELL 6: SAVE RESULTS TO GOOGLE DRIVE
# ============================================================================

print("="*70)
print("💾 SAVING RESULTS TO GOOGLE DRIVE")
print("="*70)

# Create Drive folder for results
timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
drive_save_dir = Path(f'/content/drive/MyDrive/RDD2022_Results/yolov8s_640_{timestamp}')
drive_save_dir.mkdir(parents=True, exist_ok=True)

# Source directory
results_dir = Path('/content/runs/yolov8s_640_100epochs')

if results_dir.exists():
    print(f"\n📁 Copying results to Drive...")
    print(f"   From: {results_dir}")
    print(f"   To: {drive_save_dir}")

    # Copy weights
    weights_src = results_dir / 'weights'
    if weights_src.exists():
        weights_dst = drive_save_dir / 'weights'
        shutil.copytree(weights_src, weights_dst)

        for weight_file in weights_dst.glob('*.pt'):
            size_mb = weight_file.stat().st_size / (1024 * 1024)
            print(f"   ✅ {weight_file.name}: {size_mb:.1f} MB")

    # Copy results.csv
    csv_src = results_dir / 'results.csv'
    if csv_src.exists():
        shutil.copy(csv_src, drive_save_dir / 'results.csv')
        print(f"   ✅ results.csv")

    # Copy plots
    plot_count = 0
    for plot_file in results_dir.glob('*.png'):
        shutil.copy(plot_file, drive_save_dir / plot_file.name)
        plot_count += 1
    if plot_count > 0:
        print(f"   ✅ Training plots ({plot_count} files)")

    # Save configuration
    config_path = drive_save_dir / 'config.json'
    with open(config_path, 'w') as f:
        json.dump(TRAINING_CONFIG, f, indent=2)
    print(f"   ✅ config.json")

    print(f"\n✅ All results saved to Google Drive!")
    print(f"📂 Location: {drive_save_dir}")

else:
    print(f"❌ Results directory not found: {results_dir}")

print("="*70)
# Out:
# ======================================================================
# 💾 SAVING RESULTS TO GOOGLE DRIVE
# ======================================================================
#
# 📁 Copying results to Drive...
#    From: /content/runs/yolov8s_640_100epochs
#    To: /content/drive/MyDrive/RDD2022_Results/yolov8s_640_20251213_081832
#    ✅ epoch10.pt: 42.8 MB
#    ✅ last.pt: 21.5 MB
#    ✅ epoch80.pt: 42.8 MB
#    ✅ epoch50.pt: 42.8 MB
#    ✅ epoch70.pt: 42.8 MB
#    ✅ best.pt: 21.5 MB
#    ✅ epoch40.pt: 42.8 MB
#    ✅ epoch60.pt: 42.8 MB
#    ✅ epoch0.pt: 42.8 MB
#    ✅ epoch30.pt: 42.8 MB
#    ✅ epoch20.pt: 42.8 MB
#    ✅ epoch90.pt: 42.8 MB
#    ✅ results.csv
#    ✅ Training plots (7 files)
#    ✅ config.json
#
# ✅ All results saved to Google Drive!
# 📂 Location: /content/drive/MyDrive/RDD2022_Results/yolov8s_640_20251213_081832
# ======================================================================

# %%
# ============================================================================
# CELL 7: RESULTS ANALYSIS
# ============================================================================

print("="*70)
print("📊 RESULTS ANALYSIS")
print("="*70)

# Load results
results_csv = results_dir / 'results.csv'

if results_csv.exists():
    df = pd.read_csv(results_csv)

    # Final metrics
    final_map50 = df['metrics/mAP50(B)'].iloc[-1]
    final_map50_95 = df['metrics/mAP50-95(B)'].iloc[-1]
    best_map50 = df['metrics/mAP50(B)'].max()
    best_epoch = df['metrics/mAP50(B)'].idxmax() + 1

    print(f"\n🎯 FINAL RESULTS (Epoch 100):")
    print(f"   mAP@50: {final_map50:.4f} ({final_map50*100:.2f}%)")
    print(f"   mAP@50-95: {final_map50_95:.4f} ({final_map50_95*100:.2f}%)")

    print(f"\n🏆 BEST RESULTS:")
    print(f"   Best mAP@50: {best_map50:.4f} ({best_map50*100:.2f}%)")
    print(f"   Best Epoch: {best_epoch}")

    print(f"\n📈 vs BASELINE:")
    baseline = 0.5882  # YOLOv8n baseline
    improvement = (final_map50 - baseline) * 100
    print(f"   Baseline (YOLOv8n): {baseline*100:.2f}%")
    print(f"   Improvement: +{improvement:.2f}%")

    # Target achievement
    target_min, target_max = 0.64, 0.66
    if final_map50 >= target_min:
        if final_map50 <= target_max:
            print(f"\n✅ TARGET ACHIEVED! ({final_map50*100:.1f}% within {target_min*100:.0f}-{target_max*100:.0f}%)")
        else:
            print(f"\n🎉 TARGET EXCEEDED! ({final_map50*100:.1f}% > {target_max*100:.0f}%)")
    else:
        shortfall = (target_min - final_map50) * 100
        print(f"\n⚠️ Below target by {shortfall:.1f}%")

    # Training progression
    print(f"\n📈 TRAINING PROGRESSION:")
    milestones = [10, 25, 50, 75, 100]
    for ep in milestones:
        if ep <= len(df):
            map_val = df['metrics/mAP50(B)'].iloc[ep-1]
            print(f"   Epoch {ep:3d}: {map_val*100:5.2f}%")

else:
    print("❌ Results CSV not found")

print("="*70)
# Out:
# ======================================================================
# 📊 RESULTS ANALYSIS
# ======================================================================
#
# 🎯 FINAL RESULTS (Epoch 100):
#    mAP@50: 0.6246 (62.46%)
#    mAP@50-95: 0.3443 (34.43%)
#
# 🏆 BEST RESULTS:
#    Best mAP@50: 0.6254 (62.54%)
#    Best Epoch: 91
#
# 📈 vs BASELINE:
#    Baseline (YOLOv8n): 58.82%
#    Improvement: +3.64%
#
# ⚠️ Below target by 1.5%
#
# 📈 TRAINING PROGRESSION:
#    Epoch  10: 45.54%
#    Epoch  25: 57.51%
#    Epoch  50: 61.08%
#    Epoch  75: 62.14%
#    Epoch 100: 62.46%
# ======================================================================

# %%
# ============================================================================
# CELL 8: TRAINING VISUALIZATIONS
# ============================================================================

print("="*70)
print("📊 GENERATING VISUALIZATIONS")
print("="*70)

if results_csv.exists():
    df = pd.read_csv(results_csv)

    # Create figure
    fig, axes = plt.subplots(2, 2, figsize=(15, 12))
    fig.suptitle('YOLOv8s Training Results - 100 Epochs', fontsize=16, fontweight='bold')

    # Plot 1: mAP@50
    axes[0, 0].plot(df.index + 1, df['metrics/mAP50(B)'] * 100, linewidth=2, color='#2E86AB')
    axes[0, 0].axhline(y=64, color='green', linestyle='--', label='Target Min (64%)', alpha=0.7)
    axes[0, 0].axhline(y=66, color='orange', linestyle='--', label='Target Max (66%)', alpha=0.7)
    axes[0, 0].set_xlabel('Epoch', fontsize=12)
    axes[0, 0].set_ylabel('mAP@50 (%)', fontsize=12)
    axes[0, 0].set_title('Validation mAP@50 Progression', fontsize=14, fontweight='bold')
    axes[0, 0].grid(True, alpha=0.3)
    axes[0, 0].legend()

    # Plot 2: Losses
    axes[0, 1].plot(df.index + 1, df['train/box_loss'], label='Box Loss', linewidth=2)
    axes[0, 1].plot(df.index + 1, df['train/cls_loss'], label='Class Loss', linewidth=2)
    axes[0, 1].plot(df.index + 1, df['train/dfl_loss'], label='DFL Loss', linewidth=2)
    axes[0, 1].set_xlabel('Epoch', fontsize=12)
    axes[0, 1].set_ylabel('Loss', fontsize=12)
    axes[0, 1].set_title('Training Losses', fontsize=14, fontweight='bold')
    axes[0, 1].grid(True, alpha=0.3)
    axes[0, 1].legend()

    # Plot 3: Precision & Recall
    axes[1, 0].plot(df.index + 1, df['metrics/precision(B)'], label='Precision', linewidth=2)
    axes[1, 0].plot(df.index + 1, df['metrics/recall(B)'], label='Recall', linewidth=2)
    axes[1, 0].set_xlabel('Epoch', fontsize=12)
    axes[1, 0].set_ylabel('Score', fontsize=12)
    axes[1, 0].set_title('Precision & Recall', fontsize=14, fontweight='bold')
    axes[1, 0].grid(True, alpha=0.3)
    axes[1, 0].legend()

    # Plot 4: mAP@50-95
    axes[1, 1].plot(df.index + 1, df['metrics/mAP50-95(B)'] * 100, linewidth=2, color='#A23B72')
    axes[1, 1].set_xlabel('Epoch', fontsize=12)
    axes[1, 1].set_ylabel('mAP@50-95 (%)', fontsize=12)
    axes[1, 1].set_title('Validation mAP@50-95', fontsize=14, fontweight='bold')
    axes[1, 1].grid(True, alpha=0.3)

    plt.tight_layout()

    # Save to Drive
    plot_path = drive_save_dir / 'training_curves.png'
    plt.savefig(plot_path, dpi=300, bbox_inches='tight')
    print(f"✅ Visualization saved: {plot_path}")

    plt.show()

else:
    print("❌ Cannot create visualizations - results.csv not found")

print("="*70)
# Out:
# ======================================================================
# 📊 GENERATING VISUALIZATIONS
# ======================================================================
# ✅ Visualization saved: /content/drive/MyDrive/RDD2022_Results/yolov8s_640_20251213_081832/training_curves.png
# ======================================================================

# %%
# ============================================================================
# CELL 9: TEST SET VALIDATION
# ============================================================================

print("="*70)
print("🧪 TEST SET VALIDATION")
print("="*70)

# Load best model
best_model_path = results_dir / 'weights' / 'best.pt'

if best_model_path.exists():
    print(f"📥 Loading best model: {best_model_path}")
    best_model = YOLO(best_model_path)

    print("\n🔍 Running validation on test set...")
    test_results = best_model.val(
        data='/content/data.yaml',
        split='test',
        batch=16,
        imgsz=640,
        device=0,
        workers=8,
        verbose=True
    )

    print("\n📊 TEST SET RESULTS:")
    print(f"   mAP@50: {test_results.box.map50:.4f} ({test_results.box.map50*100:.2f}%)")
    print(f"   mAP@50-95: {test_results.box.map:.4f} ({test_results.box.map*100:.2f}%)")
    print(f"   Precision: {test_results.box.mp:.4f}")
    print(f"   Recall: {test_results.box.mr:.4f}")

    # Save test results
    test_results_dict = {
        'test_mAP50': float(test_results.box.map50),
        'test_mAP50_95': float(test_results.box.map),
        'test_precision': float(test_results.box.mp),
        'test_recall': float(test_results.box.mr),
    }

    test_results_path = drive_save_dir / 'test_results.json'
    with open(test_results_path, 'w') as f:
        json.dump(test_results_dict, f, indent=2)
    print(f"\n✅ Test results saved: {test_results_path}")

    print("\n" + "="*70)
    print("🎉 COMPLETE TRAINING PIPELINE FINISHED!")
    print("="*70)
    print(f"\n📂 All results saved to: {drive_save_dir}")
    print(f"\n📦 Files in Google Drive:")
    print(f"   ✅ weights/best.pt (Best model)")
    print(f"   ✅ weights/last.pt (Final checkpoint)")
    print(f"   ✅ results.csv (Training history)")
    print(f"   ✅ training_curves.png (Visualizations)")
    print(f"   ✅ test_results.json (Test set performance)")
    print(f"   ✅ config.json (Training configuration)")

else:
    print(f"❌ Best model not found: {best_model_path}")

print("="*70)
# Out:
# ======================================================================
# 🧪 TEST SET VALIDATION
# ======================================================================
# 📥 Loading best model: /content/runs/yolov8s_640_100epochs/weights/best.pt
#
# 🔍 Running validation on test set...
# Ultralytics 8.3.237 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (NVIDIA A100-SXM4-40GB, 40507MiB)
# Model summary (fused): 72 layers, 11,127,519 parameters, 0 gradients, 28.4 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 55.3±52.5 MB/s, size: 541.8 KB)
# val: Scanning /content/RDD2022/RDD_SPLIT/test/labels... 5758 images, 1790 backgrounds, 0 corrupt: 100% ━━━━━━━━━━━━ 5758/5758 758.3it/s 7.6s
# val: New cache created: /content/RDD2022/RDD_SPLIT/test/labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% ━━━━━━━━━━━━ 360/360 11.9it/s 30.4s
#                    all       5758       9675      0.659      0.597      0.625      0.341
#     longitudinal crack       2080       3925      0.633      0.563      0.588       0.33
#       transverse crack       1118       1675      0.613      0.558       0.57      0.289
#        alligator crack       1214       1537      0.695      0.649      0.688      0.367
#       other corruption       1100       1587      0.686      0.752      0.753      0.479
#                Pothole        531        951       0.67      0.461      0.528      0.242
# Speed: 0.6ms preprocess, 1.2ms inference, 0.0ms loss, 0.7ms postprocess per image
# Results saved to /content/runs/detect/val
#
# 📊 TEST SET RESULTS:
#    mAP@50: 0.6253 (62.53%)
#    mAP@50-95: 0.3412 (34.12%)
#    Precision: 0.6593
#    Recall: 0.5966
#
# ✅ Test results saved: /content/drive/MyDrive/RDD2022_Results/yolov8s_640_20251213_081832/test_results.json
#
# ======================================================================
# 🎉 COMPLETE TRAINING PIPELINE FINISHED!
# ======================================================================
#
# 📂 All results saved to: /content/drive/MyDrive/RDD2022_Results/yolov8s_640_20251213_081832
#
# 📦 Files in Google Drive:
#    ✅ weights/best.pt (Best model)
#    ✅ weights/last.pt (Final checkpoint)
#    ✅ results.csv (Training history)
#    ✅ training_curves.png (Visualizations)
#    ✅ test_results.json (Test set performance)
#    ✅ config.json (Training configuration)
# ======================================================================
